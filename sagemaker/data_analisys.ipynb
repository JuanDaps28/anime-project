# %%
from utils import DataDescriptor
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\david\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data_descriptor = DataDescriptor(
    data_query="""
        SELECT
            r.rating,
            c.genre,
            c.type,
            c.episodes
        FROM animes_ratings r
        INNER JOIN animes_catalog c
        ON
            r.anime_id = c.anime_id
        WHERE
            c.deleted = False
    """
)
# Out:
# Executing query
#         SELECT
#             r.rating,
#             c.genre,
#             c.type,
#             c.episodes
#         FROM animes_ratings r
#         INNER JOIN animes_catalog c
#         ON
#             r.anime_id = c.anime_id
#         WHERE
#             c.deleted = False

# %%
data_descriptor.get_histograms(
    variables=["rating", "episodes"],
    bins_amount={
        "rating": 10,
        "episodes": 50
    }
)

# %%
data_descriptor.get_barplots(
    variables=["type"]
)

# %%
data_descriptor.get_boxplots(
    target_variable="episodes"
)
# Out:
# c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\david\Documents\repos\anime-project\sagemaker\utils.py:140: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
data_descriptor.get_boxplots(
    target_variable="rating",
    split_variables="type"
)
# Out:
# c:\Users\david\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# c:\Users\david\Documents\repos\anime-project\sagemaker\utils.py:145: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
data_descriptor.get_scatterplots_features_vs_target(
    target_variable="rating",
    variables=["episodes", "type"]
)

# %%
data_descriptor.get_corr_matrix(
    variables=["episodes", "rating"]
)
