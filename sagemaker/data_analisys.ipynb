# %%
# !pip install -r requirements.txt

# %%
from utils import DataDescriptor
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
data_descriptor = DataDescriptor(
    data_query="""
        SELECT
            r.rating,
            c.genre,
            c.type,
            c.episodes
        FROM animes_ratings r
        INNER JOIN animes_catalog c
        ON
            r.anime_id = c.anime_id
        WHERE
            c.deleted = False
    """
)
# Out:
# Executing query
#         SELECT
#             r.rating,
#             c.genre,
#             c.type,
#             c.episodes
#         FROM animes_ratings r
#         INNER JOIN animes_catalog c
#         ON
#             r.anime_id = c.anime_id
#         WHERE
#             c.deleted = False

# %%
data_descriptor.get_histograms(
    variables=["rating", "episodes"],
    bins_amount={
        "rating": 10,
        "episodes": 50
    }
)

# %%
data_descriptor.get_barplots(
    variables=["type"]
)

# %%
data_descriptor.get_boxplots(
    target_variable="episodes"
)
# Out:
# /home/ec2-user/SageMaker/utils.py:90: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
data_descriptor.get_boxplots(
    target_variable="rating",
    split_variables="type"
)
# Out:
# /home/ec2-user/SageMaker/utils.py:95: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90)

# %%
data_descriptor.get_scatterplots_features_vs_target(
    target_variable="rating",
    variables=["episodes", "type"]
)

# %%
data_descriptor.get_corr_matrix(
    variables=["episodes", "rating"]
)
